# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv("../data/sudan.csv")
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  25.18    35.55    16.14      19.41          0.0  31.87  3.46
# 1  2015    2  23.92    34.14    15.81      18.33          0.0  23.83  4.24
# 2  2015    3  22.73    31.64    15.09      16.55          0.0  38.21  5.01
# 3  2015    4  19.15    27.35    12.88      14.47          0.0  21.07  5.72
# 4  2015    5  17.54    27.22     9.49      17.73          0.0  21.58  4.28
#
#    WS2M_MAX     PS  QV2M
# 0      5.12  96.54  6.08
# 1      5.10  96.67  4.31
# 2      6.24  96.77  6.42
# 3      6.96  96.93  3.06
# 4      5.82  96.85  2.86

# %%
df["Country"] = "Sudan"
df["Date"] = pd.to_datetime(df["YEAR"] * 1000 + df["DOY"], format="%Y%j")
df["Month"] = df["Date"].dt.month

# %%
df.replace(-999, np.nan, inplace=True)
# Out:
#       YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0     2015    1  25.18    35.55    16.14      19.41          0.0  31.87  3.46
# 1     2015    2  23.92    34.14    15.81      18.33          0.0  23.83  4.24
# 2     2015    3  22.73    31.64    15.09      16.55          0.0  38.21  5.01
# 3     2015    4  19.15    27.35    12.88      14.47          0.0  21.07  5.72
# 4     2015    5  17.54    27.22     9.49      17.73          0.0  21.58  4.28
# ...    ...  ...    ...      ...      ...        ...          ...    ...   ...
# 4103  2026   86  27.89    34.69    21.67      13.02          0.0  14.47  3.66
# 4104  2026   87  28.73    36.61    21.34      15.27          0.0   9.75  3.21
# 4105  2026   88  30.06    38.89    21.15      17.74          0.0  11.63  2.41
# 4106  2026   89  32.50    41.53    23.61      17.92          0.0  14.06  2.81
# 4107  2026   90  33.79    42.64    25.73      16.91          0.0  13.89  3.52
#
#       WS2M_MAX     PS  QV2M Country       Date  Month
# 0         5.12  96.54  6.08   Sudan 2015-01-01      1
# 1         5.10  96.67  4.31   Sudan 2015-01-02      1
# 2         6.24  96.77  6.42   Sudan 2015-01-03      1
# 3         6.96  96.93  3.06   Sudan 2015-01-04      1
# 4         5.82  96.85  2.86   Sudan 2015-01-05      1
# ...        ...    ...   ...     ...        ...    ...
# 4103      5.11  96.47  3.52   Sudan 2026-03-27      3
# 4104      4.40  96.35  2.44   Sudan 2026-03-28      3
# 4105      3.87  96.10  3.12   Sudan 2026-03-29      3
# 4106      4.87  95.93  4.18   Sudan 2026-03-30      3
# 4107      5.00  95.89  4.47   Sudan 2026-03-31      3
#
# [4108 rows x 15 columns]

# %%
duplicates = df.duplicated().sum()
print(f"Duplicate rows found: {duplicates}")
if duplicates > 0:
    df.drop_duplicates(inplace=True)
# Out:
# Duplicate rows found: 0

# %%
df.describe()
# Out:
#               YEAR          DOY          T2M      T2M_MAX      T2M_MIN  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean   2020.131451   180.121227    28.759007    36.773914    21.508510
# min    2015.000000     1.000000    13.180000    21.040000     5.930000
# 25%    2017.000000    86.000000    25.560000    33.730000    17.497500
# 50%    2020.000000   179.000000    29.160000    37.020000    22.890000
# 75%    2023.000000   272.000000    32.510000    40.330000    25.430000
# max    2026.000000   366.000000    37.990000    45.960000    32.170000
# std       3.248907   106.294767     4.681305     4.400065     5.091142
#
#          T2M_RANGE  PRECTOTCORR         RH2M         WS2M     WS2M_MAX  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean     15.265404     0.643875    31.359192     3.484253     5.157378
# min       3.420000     0.000000     4.690000     0.610000     1.030000
# 25%      13.280000     0.000000    17.407500     2.730000     4.267500
# 50%      15.810000     0.000000    26.630000     3.490000     5.120000
# 75%      17.680000     0.010000    40.535000     4.220000     6.020000
# max      22.480000    66.490000    87.160000     7.150000     9.050000
# std       3.298919     3.057672    17.851849     1.040667     1.280238
#
#                 PS         QV2M                 Date        Month
# count  4108.000000  4108.000000                 4108  4108.000000
# mean     96.346273     7.864557  2020-08-15 12:00:00     6.423564
# min      95.660000     1.160000  2015-01-01 00:00:00     1.000000
# 25%      96.160000     3.730000  2017-10-23 18:00:00     3.000000
# 50%      96.310000     5.895000  2020-08-15 12:00:00     6.000000
# 75%      96.510000    12.500000  2023-06-08 06:00:00     9.000000
# max      97.310000    19.440000  2026-03-31 00:00:00    12.000000
# std       0.266927     4.880934                  NaN     3.477046

# %%
missing = df.isna().sum()
missing_percent = (missing / len(df)) * 100

missing_df = pd.DataFrame({
    "Missing Count": missing,
    "Missing %": missing_percent
})

missing_df
# Out:
#              Missing Count  Missing %
# YEAR                     0        0.0
# DOY                      0        0.0
# T2M                      0        0.0
# T2M_MAX                  0        0.0
# T2M_MIN                  0        0.0
# T2M_RANGE                0        0.0
# PRECTOTCORR              0        0.0
# RH2M                     0        0.0
# WS2M                     0        0.0
# WS2M_MAX                 0        0.0
# PS                       0        0.0
# QV2M                     0        0.0
# Country                  0        0.0
# Date                     0        0.0
# Month                    0        0.0

# %%
missing_df[missing_df["Missing %"] > 5]
# Out:
# Empty DataFrame
# Columns: [Missing Count, Missing %]
# Index: []

# %%
from scipy.stats import zscore

cols = ["T2M", "T2M_MAX", "T2M_MIN",
        "PRECTOTCORR", "RH2M", "WS2M", "WS2M_MAX"]

z_scores = df[cols].apply(zscore)

outliers = np.abs(z_scores) > 3

print("Outlier rows:", outliers.any(axis=1).sum())
# Out:
# Outlier rows: 84

# %% [markdown]
# I choose to CAP outliers instead of removing them because climate extremes are meaningful and part of real weather variability. This preserves time-series integrity

# %%
for col in cols:
    mean = df[col].mean()
    std = df[col].std()

    upper = mean + 3 * std
    lower = mean - 3 * std
    df[col] = np.where(df[col] > upper, upper, df[col])
    df[col] = np.where(df[col] < lower, lower, df[col])

# %%
df[cols].head()
# Out:
#      T2M  T2M_MAX  T2M_MIN  PRECTOTCORR   RH2M  WS2M  WS2M_MAX
# 0  25.18    35.55    16.14          0.0  31.87  3.46      5.12
# 1  23.92    34.14    15.81          0.0  23.83  4.24      5.10
# 2  22.73    31.64    15.09          0.0  38.21  5.01      6.24
# 3  19.15    27.35    12.88          0.0  21.07  5.72      6.96
# 4  17.54    27.22     9.49          0.0  21.58  4.28      5.82

# %%
df = df.sort_values("Date")
df = df.ffill()

# %%
df = df.dropna(thresh=int(0.7 * df.shape[1]))

# %%
df.describe()
# Out:
#               YEAR          DOY          T2M      T2M_MAX      T2M_MIN  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean   2020.131451   180.121227    28.759607    36.775397    21.508584
# min    2015.000000     1.000000    14.715092    23.573720     6.235085
# 25%    2017.000000    86.000000    25.560000    33.730000    17.497500
# 50%    2020.000000   179.000000    29.160000    37.020000    22.890000
# 75%    2023.000000   272.000000    32.510000    40.330000    25.430000
# max    2026.000000   366.000000    37.990000    45.960000    32.170000
# std       3.248907   106.294767     4.679431     4.395328     5.090917
#
#          T2M_RANGE  PRECTOTCORR         RH2M         WS2M     WS2M_MAX  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean     15.265404     0.487103    31.358426     3.484008     5.157435
# min       3.420000     0.000000     4.690000     0.610000     1.316666
# 25%      13.280000     0.000000    17.407500     2.730000     4.267500
# 50%      15.810000     0.000000    26.630000     3.490000     5.120000
# 75%      17.680000     0.010000    40.535000     4.220000     6.020000
# max      22.480000     9.816892    84.914738     6.606253     8.998091
# std       3.298919     1.665770    17.849513     1.039885     1.279981
#
#                 PS         QV2M                 Date        Month
# count  4108.000000  4108.000000                 4108  4108.000000
# mean     96.346273     7.864557  2020-08-15 12:00:00     6.423564
# min      95.660000     1.160000  2015-01-01 00:00:00     1.000000
# 25%      96.160000     3.730000  2017-10-23 18:00:00     3.000000
# 50%      96.310000     5.895000  2020-08-15 12:00:00     6.000000
# 75%      96.510000    12.500000  2023-06-08 06:00:00     9.000000
# max      97.310000    19.440000  2026-03-31 00:00:00    12.000000
# std       0.266927     4.880934                  NaN     3.477046

# %%
df.to_csv("../data/sudan_clean.csv", index=False)

# %% [markdown]
# Monthly Average Temperature (Trend Over Time)

# %%
monthly_temp = df.groupby("Month")["T2M"].mean()

plt.figure(figsize=(10,5))
plt.plot(monthly_temp.index, monthly_temp.values, marker="o")
plt.title("Monthly Average Temperature (Ethiopia)")
plt.xlabel("Month")
plt.ylabel("Temperature (°C)")
plt.xticks(range(1,13))
plt.grid(True)
plt.show()

# %% [markdown]
# # Monthly Rainfall Pattern

# %%
monthly_rain = df.groupby("Month")["PRECTOTCORR"].sum()

plt.figure(figsize=(10,5))
plt.bar(monthly_rain.index, monthly_rain.values)
plt.title("Monthly Total Rainfall (Ethiopia)")
plt.xlabel("Month")
plt.ylabel("Rainfall (mm)")
plt.xticks(range(1,13))
plt.show()

# %% [markdown]
# # Correlation Heatmap

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df[cols].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap - Climate Variables")
plt.show()

# %% [markdown]
# # Scatter Plot (Temperature vs Humidity)

# %%
plt.figure(figsize=(6,5))
plt.scatter(df["T2M"], df["RH2M"], alpha=0.5)
plt.title("Temperature vs Humidity")
plt.xlabel("Temperature (T2M)")
plt.ylabel("Humidity (RH2M)")
plt.show()

# %% [markdown]
# # Wind vs Temperature Range

# %%
plt.figure(figsize=(6,5))
plt.scatter(df["T2M_RANGE"], df["WS2M"], alpha=0.5)
plt.title("Temperature Range vs Wind Speed")
plt.xlabel("Temperature Range")
plt.ylabel("Wind Speed")
plt.show()

# %% [markdown]
# # Rainfall Distribution (Skew Check)

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["PRECTOTCORR"], bins=30, kde=True)
plt.title("Rainfall Distribution")
plt.yscale("log")  # helps if skewed
plt.show()
